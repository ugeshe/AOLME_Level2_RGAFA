# %%
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/bg_wall_1.png
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/Puppy.pickle
# Out:
# --2021-06-21 02:35:48--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57752 (56K) [text/plain]
# Saving to: ‘aolme2.py.3’
#
# aolme2.py.3         100%[===================>]  56.40K  --.-KB/s    in 0.008s
#
# 2021-06-21 02:35:48 (6.98 MB/s) - ‘aolme2.py.3’ saved [57752/57752]
#
# --2021-06-21 02:35:48--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/bg_wall_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112447 (110K) [image/png]
# Saving to: ‘bg_wall_1.png.3’
#
# bg_wall_1.png.3     100%[===================>] 109.81K  --.-KB/s    in 0.01s
#
# 2021-06-21 02:35:48 (7.16 MB/s) - ‘bg_wall_1.png.3’ saved [112447/112447]
#
# --2021-06-21 02:35:48--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/Puppy.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9191 (9.0K) [application/octet-stream]
# Saving to: ‘Puppy.pickle.3’
#
# Puppy.pickle.3      100%[===================>]   8.98K  --.-KB/s    in 0s
#
# 2021-06-21 02:35:48 (74.8 MB/s) - ‘Puppy.pickle.3’ saved [9191/9191]

# %%
from aolme2 import vid, spr, load_img, plot_img, clean
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import cv2
from IPython.display import HTML

# Close all of the figures
clean()

# Read the puppy sprite from Puppy.pickle.
my_sprite = spr()
my_sprite.set_sprite("Puppy")

# Read the background image
bac=load_img("bg_wall_1.png")
video_rows=bac.shape[0]  # number of rows.
video_cols=bac.shape[1]  # number of columns.

# Init video
my_video = vid('TSP Puppy',video_rows,video_cols)
my_video.set_back('house',bac)
my_video.init_video('house', 0, 0)

# Set sprite inside "my_video"
my_video.set_sprite('puppy',my_sprite)


######## Starting point for the puppy ########
start_row = 250
start_col = 250
my_video.place_sprite('puppy',start_row,start_col)


# Second frame 
rows_move = 0
cols_move = 400
my_video.set_new_frame('house',0,0)
my_video.move_sprite('puppy',rows_move,cols_move,Trace=True)


# Third frame
rows_move = 250
cols_move = 200
my_video.set_new_frame('house',0,0)
my_video.move_sprite('puppy',rows_move,cols_move,Trace=True)


# Third frame 
rows_move = -30
cols_move = -380
my_video.set_new_frame('house',0,0)
my_video.move_sprite('puppy',rows_move,cols_move,Trace=True)

my_video.draw_path('puppy')

print(" ")
print(my_video)
print(" ")

# Display the result
fig = plt.figure(figsize=(8,8))  #Display size specification 
frame_list = []
for i in range(len(my_video.video)):
    frame = plt.imshow(cv2.cvtColor(my_video.video[i], cv2.COLOR_BGR2RGB), animated=True)
    plt.axis('off')
    frame_list.append([frame])
  
anime = animation.ArtistAnimation(fig, frame_list, interval=500, repeat_delay=1000)    
plt.close()
# Out:
# set_sprite(sprite_name=Puppy)
# Reading file =  Puppy.pickle
# (51, 44)
# Reading file =  bg_wall_1.png
# aolme2(video_name=TSP Puppy, num_of_rows=944, num_of_cols=1316)
# draw_path()
#
# Video name=TSP Puppy (rows=944, cols=1316)
# Sprites = ['puppy']
# Background images = ['house']
# Number of frames = 4
# puppy has travelled 1101.34 pixels.

# %%
# Display the video
HTML(anime.to_html5_video())
# Out:
# <video width="576" height="576" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
