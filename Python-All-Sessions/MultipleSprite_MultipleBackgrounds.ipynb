# %%
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backgroundMario.jpg
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backgroundCastle.png
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/B1.pickle
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/mario.pickle
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/AOLME.py
# Out:
# --2021-08-13 05:42:56--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57877 (57K) [text/plain]
# Saving to: ‘aolme2.py’
#
# aolme2.py           100%[===================>]  56.52K  --.-KB/s    in 0.004s
#
# 2021-08-13 05:42:56 (13.6 MB/s) - ‘aolme2.py’ saved [57877/57877]
#
# --2021-08-13 05:42:56--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backgroundMario.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78353 (77K) [image/jpeg]
# Saving to: ‘backgroundMario.jpg’
#
# backgroundMario.jpg 100%[===================>]  76.52K  --.-KB/s    in 0.005s
#
# 2021-08-13 05:42:56 (16.3 MB/s) - ‘backgroundMario.jpg’ saved [78353/78353]
#
# --2021-08-13 05:42:56--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backgroundCastle.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 241502 (236K) [image/png]
# Saving to: ‘backgroundCastle.png’
#
# backgroundCastle.pn 100%[===================>] 235.84K  --.-KB/s    in 0.01s
#
# 2021-08-13 05:42:56 (22.1 MB/s) - ‘backgroundCastle.png’ saved [241502/241502]
#
# --2021-08-13 05:42:56--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/B1.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101693 (99K) [application/octet-stream]
# Saving to: ‘B1.pickle’
#
# B1.pickle           100%[===================>]  99.31K  --.-KB/s    in 0.006s
#
# 2021-08-13 05:42:57 (16.5 MB/s) - ‘B1.pickle’ saved [101693/101693]
#
# --2021-08-13 05:42:57--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/mario.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50399 (49K) [application/octet-stream]
# Saving to: ‘mario.pickle’
#
# mario.pickle        100%[===================>]  49.22K  --.-KB/s    in 0.004s
#
# 2021-08-13 05:42:57 (11.9 MB/s) - ‘mario.pickle’ saved [50399/50399]
#
# --2021-08-13 05:42:57--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/AOLME.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22948 (22K) [text/plain]
# Saving to: ‘AOLME.py’
#
# AOLME.py            100%[===================>]  22.41K  --.-KB/s    in 0s
#
# 2021-08-13 05:42:57 (87.8 MB/s) - ‘AOLME.py’ saved [22948/22948]

# %%
from IPython.display import HTML
# AOLME2 classes and functions that we will be demonstrating:
from aolme2 import vid, spr, load_img, plot_img, clean
import AOLME 
import numpy as np

# Use reset in IPython to clean up the variables.
# Clean() closes all of the Windows.
clean()

# Constructor for video class
videoName = "Video1"
num_of_rows = 500
num_of_cols = 700
my_video = vid(videoName, num_of_rows, num_of_cols)

##############################################################

# Add a FIRST BACKGROUND 
backMario = load_img("backgroundMario.jpg") # Background image file
my_video.set_back('back1', backMario)       # Save it in the video
my_video.show_back('back1') # Show it


# Add a SECOND BACKGROUND 
backCastle = load_img("backgroundCastle.png") # Background image file
my_video.set_back('back2', backCastle)       # Save it in the video
my_video.show_back('back2') # Show it

##############################################################

# Add a FIRST SPRITE
my_1st_sprite = spr()          # Construct a sprite
my_1st_sprite.set_sprite("B1") # Load it from the file B1.pickle
my_1st_sprite.show("B1")


# Add a SECOND SPRITE
my_2nd_sprite = spr()          # Construct a sprite
my_2nd_sprite.set_sprite("mario") # Load it from the file B1.pickle
my_2nd_sprite.show("mario")

##############################################################

# Make the FIRST sprite available to your video:
my_sprite_name_1 = "Bowser"
my_video.set_sprite(my_sprite_name_1, my_1st_sprite)

# Make the SECOND sprite available to your video:
my_sprite_name_2 = "SuperMario"
my_video.set_sprite(my_sprite_name_2, my_2nd_sprite)


##############################################################

# Create the first video frame with FIRST BACKGROUND
left_offset = 120
top_offset  = 50
my_video.init_video('back1', top_offset, left_offset)  # First video frame

# Place the SECOND SPRITE
row_center    = 400
column_center = 100
my_video.place_sprite(my_sprite_name_2, row_center, column_center)


my_video.show_last_frame()             # You can see the frame

### Change background
left_offset = 20
top_offset  = 130
my_video.set_new_frame('back2', top_offset, left_offset) 


# Place the SECOND SPRITE
row_center    = 300
column_center = 200
my_video.place_sprite(my_sprite_name_2, row_center, column_center)

# Place the FIRST SPRITE
row_center    = 140
column_center = 500
my_video.place_sprite(my_sprite_name_1, row_center, column_center)


my_video.show_last_frame()             # You can see the frame


play_video = AOLME.vid_show(my_video.video, 1)
HTML(play_video.to_html5_video())
# Out:
# aolme2(video_name=Video1, num_of_rows=500, num_of_cols=700)
# Reading file =  backgroundMario.jpg
# show_back(back1)
# Reading file =  backgroundCastle.png
# show_back(back2)
# set_sprite(sprite_name=B1)
# Reading file =  B1.pickle
# (168, 151)
# (157, 133)
# 157 133
# set_sprite(sprite_name=mario)
# Reading file =  mario.pickle
# (153, 82)
# (150, 80)
# 150 80
# show_last_frame()
# show_last_frame()
# <video width="1080" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
