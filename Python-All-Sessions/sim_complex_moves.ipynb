# %%
time = 0
dist = 100
while(time <= 10):
    if(dist > 100): 
        print("ROBOT is too ????")    
        print("ROBOT is moving ????")
        dist = dist - 10        
    else:
        print("ROBOT is too ???")
        print("ROBOT is moving ????")
        dist = dist + 5
        
        print("ROBOT needs to turn")            
    time = time + 1   # Increase time
# Out:
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ????
# ROBOT is moving ????
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ????
# ROBOT is moving ????
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ????
# ROBOT is moving ????
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ???
# ROBOT is moving ????
# ROBOT needs to turn
# ROBOT is too ????
# ROBOT is moving ????
