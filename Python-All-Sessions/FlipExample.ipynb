# %%
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/face.pickle
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backWhite.jpg
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/ResultFlipExample.png
# Out:
# --2021-08-16 23:57:40--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58069 (57K) [text/plain]
# Saving to: ‘aolme2.py’
#
# aolme2.py           100%[===================>]  56.71K  --.-KB/s    in 0.01s
#
# 2021-08-16 23:57:41 (3.96 MB/s) - ‘aolme2.py’ saved [58069/58069]
#
# --2021-08-16 23:57:41--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/face.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1037739 (1013K) [application/octet-stream]
# Saving to: ‘face.pickle’
#
# face.pickle         100%[===================>]   1013K  --.-KB/s    in 0.07s
#
# 2021-08-16 23:57:42 (13.8 MB/s) - ‘face.pickle’ saved [1037739/1037739]
#
# --2021-08-16 23:57:42--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backWhite.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18583 (18K) [image/jpeg]
# Saving to: ‘backWhite.jpg’
#
# backWhite.jpg       100%[===================>]  18.15K  --.-KB/s    in 0.001s
#
# 2021-08-16 23:57:42 (14.7 MB/s) - ‘backWhite.jpg’ saved [18583/18583]
#
# --2021-08-16 23:57:42--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/ResultFlipExample.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 781425 (763K) [image/png]
# Saving to: ‘ResultFlipExample.png’
#
# ResultFlipExample.p 100%[===================>] 763.11K  --.-KB/s    in 0.05s
#
# 2021-08-16 23:57:43 (13.6 MB/s) - ‘ResultFlipExample.png’ saved [781425/781425]

# %%
# AOLME2 classes and functions that we will be demonstrating:
from aolme2 import vid, spr, load_img, plot_img, clean

# Close all of the old figures.
clean()

# Create a sprite from an external file:
sprite_face = spr()
sprite_face.set_sprite("face")

# Load a background image
backWhite = load_img("backWhite.jpg")

# Initialize the video and place the background frame:
num_of_rows = 576
num_of_cols = 1024
my_video = vid('Example 1', num_of_rows, num_of_cols)
my_video.set_back('back2', backWhite)

row_offset = 0
col_offset = 0
my_video.init_video('back2', row_offset, col_offset)


# Save the sprite in the video.
my_video.set_sprite('face',sprite_face)

# You need to copy and modify the following three lines to generate multiple sprites in one background
# Fix the parameters to the commands given below:
row_center    = 200
column_center = 830
my_video.place_sprite('face', row_center, column_center)




# Show last frame
my_video.show_last_frame()

# Challenge
print("Can you produce the following challenge image?")
Challenge_img = load_img ('ResultFlipExample.png')
plot_img (Challenge_img, "Example result")
# Out:
# set_sprite(sprite_name=face)
# Reading file =  face.pickle
# (415, 625)
# (377, 359)
# Reading file =  backWhite.jpg
# aolme2(video_name=Example 1, num_of_rows=576, num_of_cols=1024)
# show_last_frame()
# Can you produce the following challenge image?
# Reading file =  ResultFlipExample.png
