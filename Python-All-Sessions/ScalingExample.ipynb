# %%
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/B1.pickle
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backgroundMario.jpg
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/resultScalingExample.png
# Out:
# --2021-06-22 06:09:46--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/aolme2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57877 (57K) [text/plain]
# Saving to: ‘aolme2.py’
#
# aolme2.py           100%[===================>]  56.52K  --.-KB/s    in 0.006s
#
# 2021-06-22 06:09:47 (8.89 MB/s) - ‘aolme2.py’ saved [57877/57877]
#
# --2021-06-22 06:09:47--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/B1.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101693 (99K) [application/octet-stream]
# Saving to: ‘B1.pickle’
#
# B1.pickle           100%[===================>]  99.31K  --.-KB/s    in 0.01s
#
# 2021-06-22 06:09:47 (8.72 MB/s) - ‘B1.pickle’ saved [101693/101693]
#
# --2021-06-22 06:09:47--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/backgroundMario.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78353 (77K) [image/jpeg]
# Saving to: ‘backgroundMario.jpg’
#
# backgroundMario.jpg 100%[===================>]  76.52K  --.-KB/s    in 0.009s
#
# 2021-06-22 06:09:47 (8.37 MB/s) - ‘backgroundMario.jpg’ saved [78353/78353]
#
# --2021-06-22 06:09:47--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/Python-All-Sessions/resultScalingExample.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 438673 (428K) [image/png]
# Saving to: ‘resultScalingExample.png’
#
# resultScalingExampl 100%[===================>] 428.39K  --.-KB/s    in 0.03s
#
# 2021-06-22 06:09:48 (15.2 MB/s) - ‘resultScalingExample.png’ saved [438673/438673]

# %%
# AOLME2 classes and functions that we will be demonstrating:
from aolme2 import vid, spr, load_img, plot_img, clean


# Init example sprite
my_sprite = spr()
my_sprite.set_sprite("B1")

# Init video
bac = load_img("backgroundMario.jpg")

my_video = vid('Scaling Challenge',560,900)
my_video.set_back('back1',bac)
my_video.init_video('back1', 0, 100)

my_video.set_sprite('B1',my_sprite)


######## Fix the scale_sprite() commands below ########
# After you figure out the parameters, try solving 
# the problem using a for-loop
scaleFactor=1
row_center = 300
col_center = 100
my_video.scale_sprite('B1', row_center, col_center,scaleFactor)

# Show last frame
my_video.show_last_frame() 

print("Scaling challenge: produce this image")
scale_challenge = load_img("resultScalingExample.png")
plot_img(scale_challenge, "Scale Challenge")
# Out:
# set_sprite(sprite_name=B1)
# Reading file =  B1.pickle
# (168, 151)
# Reading file =  backgroundMario.jpg
# aolme2(video_name=Scaling Challenge, num_of_rows=560, num_of_cols=900)
# show_last_frame()
# Scaling challenge: produce this image
# Reading file =  resultScalingExample.png
