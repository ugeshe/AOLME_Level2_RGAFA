# %%
print("Robot distance simulation")

dist = 100  
print("Assume that Robot sensor gives: ")
print("Initially: dist=", dist)

while(dist > 10):
    print("Robot moves closer ... ")          
    dist = dist - 5    
    print ("Robot must sense the distance to target again. ")              
    print("dist=", dist)

print("Final: dist=", dist)

print(" ")
print("Assume that the robot needs to get closer.")
print("Which value do you need to change?")

print(" ")
print("Suppose that the robot moves faster")
print("Which valude do you need to change?")
# Out:
# Robot distance simulation
# Assume that Robot sensor gives:
# Initially: dist= 100
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 95
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 90
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 85
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 80
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 75
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 70
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 65
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 60
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 55
# Robot moves closer ...
# Robot must sense the distance to target again.
# dist= 50
# Robot moves closer ...
# ...
