# %%
# !pip install pygame
# Out:
# ...
#      |████████████████████████████████| 11.8 MB 6.4 MB/s
# ...

# %%
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/robotSimulation.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/settings.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/robot.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/maze.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/AOLME.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/robot.png
# Out:
# --2021-07-22 19:56:50--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/robotSimulation.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13577 (13K) [text/plain]
# Saving to: ‘robotSimulation.py’
#
# robotSimulation.py  100%[===================>]  13.26K  --.-KB/s    in 0s
#
# 2021-07-22 19:57:05 (71.9 MB/s) - ‘robotSimulation.py’ saved [13577/13577]
#
# --2021-07-22 19:57:05--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/ColorDetMazeSimulation/ColorDetMazeSimulationGoogleColab/settings.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# ...

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"
from robotSimulation import RobotSimulation
from IPython.display import HTML
import AOLME
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
if __name__ == '__main__':
    # Make a game instance, and run the game.
       
    """ Type activities for robot movemxents:
        Move forward:  gopi.fw(second)
        Move backward: gopi.bw(second)
        Move left:     gopi.lt(second)
        Move right:    gopi.rt(second)
        Turn left:     gopi.ltd(degree)
        Turn right:    gopi.rtd(degree)
    """
    frame_list = []
    
    red_range   = [50, 255]
    green_range = [0, 90]
    blue_range  = [0, 60]

    detect_color    = (red_range, green_range, blue_range)
    gopi            = RobotSimulation(detect_color, frame_list)
    dis_robot_color = gopi._update_screen()
    collision       = False
    time = True
    
    while(dis_robot_color>10 and time == True):
        
        if collision == False:
            collision, time = gopi.fw(1)
            
        else:
            collision, time = gopi.lt(1)
            collision, time = gopi.bw(1)
            gopi.rtd(90)
            collision, time = gopi.fw(3)
            gopi.ltd(90)
            
            collision = False
        dis_robot_color=gopi._update_screen()
        print(time)
        
    #gopi.run_game()
    
    
    
    all_frame = gopi.frame_list
    print(len(all_frame))
    fps = 30
    play_video = AOLME.vid_show(all_frame, fps) 
    print('Video is ready')
# Out:
# 325 275
# Robot position = (225, 545)    Color(r, g, b) = (238, 164, 127)
# Move forward 225 545
# 325 275
# Robot position = (225, 535)    Color(r, g, b) = (238, 164, 127)
# 325 275
# Robot position = (225, 535)    Color(r, g, b) = (238, 164, 127)
# True
# Move forward 225 535
# 325 275
# Robot position = (225, 525)    Color(r, g, b) = (238, 164, 127)
# 325 275
# Robot position = (225, 525)    Color(r, g, b) = (238, 164, 127)
# True
# Move forward 225 525
# 325 275
# Robot position = (225, 515)    Color(r, g, b) = (238, 164, 127)
# 325 275
# Robot position = (225, 515)    Color(r, g, b) = (238, 164, 127)
# True
# Move forward 225 515
# 325 275
# Robot position = (225, 505)    Color(r, g, b) = (238, 164, 127)
# 325 275
# Robot position = (225, 505)    Color(r, g, b) = (238, 164, 127)
# True
# Move forward 225 505
# 325 275
# Robot position = (225, 495)    Color(r, g, b) = (255, 255, 0)
# 325 275
# Robot position = (225, 495)    Color(r, g, b) = (255, 255, 0)
# True
# ...

# %%
final_video = play_video.to_html5_video()

# %%
HTML("""
<video controls>
      <source src="%s" >
</video>
""" % final_video)
# Out:
# <video controls>
#       <source src="<video width="1080" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
